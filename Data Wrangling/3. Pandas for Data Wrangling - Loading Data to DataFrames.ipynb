# %% [markdown]
# # Objective : Loading Data into DataFrames
#
# 1. Sources from which dataframes can be created
# 2. Loading from CSV
# 3. Loading from JSON - Structured & Unstructured
# 4. Loading from Excel
# 5. Loading from Database

# %% [markdown]
# ### 1. Sources from which dataframes can be created
# * Reading data from different sources, here is the list.
# * Also, includes writing data to different sources.

# %% [markdown]
# ![Screenshot%20%28835%29.png](attachment:Screenshot%20%28835%29.png)

# %%
import pandas as pd

# %% [markdown]
# ### 2. Reading CSV

# %%
jahadeesh_data = pd.read_csv('C:/Users/jagadeesh baman/Documents/Jagadeesh/data science/1.Linear Regreesion/Sales_data.csv')

# %%
#to read top 5 rows from the data
jahadeesh_data.head()
# Out:
#    Student_Population  Sales_of_books
# 0                   2              58
# 1                   6             105
# 2                   8              88
# 3                   8             118
# 4                  12             117

# %% [markdown]
# ### 3. Loading from JSON

# %%
import json

# %%
import pandas as pd

# %%
with open('C:/Users/jagadeesh baman/Desktop/sample.json') as f:
    jagadeesh_data = json.load(f)

# %%
jagadeesh_data
# Out:
# {'firstName': 'Joe',
#  'lastName': 'Jackson',
#  'gender': 'male',
#  'age': 28,
#  'address': {'streetAddress': '101', 'city': 'San Diego', 'state': 'CA'},
#  'phoneNumbers': [{'type': 'home', 'number': '7349282382'}]}

# %% [markdown]
# ### 4. Loading Excel

# %%
jagadeesh_anova_data = pd.read_excel('C:/Users/jagadeesh baman/Documents/alldata/anova2.xlsx')

# %%
jagadeesh_anova_data
# Out:
#           Unnamed: 0  business  engineering  arts_and_science
# 0  three_hour_review         1            2                 3
# 1    one_day_program         4            5                 6
# 2   ten_weeks_course         7            8                 9

# %% [markdown]
# ### 5. Loading from databases
# * No matter what your database is, all you need to do is create a connection object.

# %%
#here iam connecting PostgreSQL.

# %%
# %load_ext sql

# %%
import psycopg2

# %%
# %sql postgresql://postgres:********@localhost:5432/postgres
            
            
#I CHANGED MY PASSWORD AFTER RUNNING THIS CELL,do write your passowrd at ******

# %%
# %%sql
# SELECT * FROM Workers
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 8 rows affected.
# [(1, 'Monika                   ', 'Arora                    ', 100000, datetime.datetime(2014, 2, 2, 9, 0), 'HR                       '),
#  (2, 'Niharika                 ', 'Verma                    ', 80000, datetime.datetime(2011, 6, 14, 9, 0), 'Admin                    '),
#  (3, 'Vishal                   ', 'Singhal                  ', 300000, datetime.datetime(2020, 2, 14, 9, 0), 'HR                       '),
#  (4, 'Amitabh                  ', 'Singh                    ', 500000, datetime.datetime(2020, 2, 14, 9, 0), 'Admin                    '),
#  (5, 'Vivek                    ', 'Bhati                    ', 500000, datetime.datetime(2011, 6, 14, 9, 0), 'Admin                    '),
#  (6, 'Vipul                    ', 'Diwan                    ', 200000, datetime.datetime(2011, 6, 14, 9, 0), 'Account                  '),
# ...
